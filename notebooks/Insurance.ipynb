# %%
import pandas as pd

# %%
df = pd.read_csv('insurance.csv')

# %%
df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.sex.value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
df.smoker.value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
df.children.value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
df.region.value_counts()
# Out:
# southeast    364
# northwest    325
# southwest    325
# northeast    324
# Name: region, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.boxplot(df['expenses'])
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.boxplot(df['age'])
plt.grid(True)
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(8,5))
df['sex'].value_counts().plot(kind='bar')

# %%
plt.figure(figsize=(8,5))
df.smoker.value_counts().plot(kind='bar')

# %%
plt.figure(figsize=(10,6))
df.region.value_counts().plot(kind='bar')

# %%
plt.figure(figsize=(10,6))

df.children.value_counts().plot(kind='bar')

# %%
plt.figure(figsize=(15,7))
plt.title("Distribution Of Age",fontsize=25)
bp1=sns.histplot(x='age',data=df,bins=46,color='orange')
bp1.set_xlabel("Age", fontsize=16)
bp1.set_ylabel("Count", fontsize=16)
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(15,7))
plt.title("Distribution Of BMI",fontsize=25)
g=sns.distplot(df['bmi'])
g.set_xlabel("bmi", fontsize=16)
g.set_ylabel("Frequency", fontsize=16)
# Out:
# <ipython-input-18-838bdf9f30dd>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   g=sns.distplot(df['bmi'])
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x='bmi',data=df)

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x='expenses',data=df)

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x='age',data=df)

# %%
plt.figure(figsize=(15,5))
sns.histplot(x='expenses',data=df)

# %%
plt.figure(figsize=(15,6))
bp2 = sns.countplot(x='smoker',data=df)
bp2.set_xlabel("smokers", fontsize=16)
bp2.set_ylabel("count", fontsize=16)
# Out:
# Text(0, 0.5, 'count')

# %%
plt.figure(figsize=(15,6))
plt.title("Smoker Vs Expenses",fontsize=25)
bp3=sns.barplot(x='smoker',y='expenses',data=df)
bp3.set_xlabel("smoker", fontsize=16)
bp3.set_ylabel("expenses", fontsize=16)
# Out:
# Text(0, 0.5, 'expenses')

# %%
plt.figure(figsize=(15,6))
bp4=sns.barplot(x='children',y='expenses',data=df)
bp4.set_xlabel("childrens", fontsize=16)
bp4.set_ylabel("expenses", fontsize=16)
# Out:
# Text(0, 0.5, 'expenses')

# %%
plt.figure(figsize=(15,6))
bp5=sns.barplot(x='region',y='expenses',data=df)
bp5.set_xlabel("region", fontsize=16)
bp5.set_ylabel("expenses", fontsize=16)
# Out:
# Text(0, 0.5, 'expenses')

# %%
plt.figure(figsize=(15,6))
bp6=sns.countplot(x=df.smoker,hue=df.sex)
bp6.set_xlabel("smoker", fontsize=16)
bp6.set_ylabel("count", fontsize=16)
# Out:
# Text(0, 0.5, 'count')

# %%
plt.figure(figsize=(15,6))
plt.title("Age vs Expenses",fontsize=25)
bp7=sns.regplot(x='age',y='expenses',data=df)
bp7.set_xlabel("Age", fontsize=16)
bp7.set_ylabel("Expenses", fontsize=16)
# Out:
# Text(0, 0.5, 'Expenses')

# %%
plt.figure(figsize=(15,6))
plt.title("BMI vs Expenses",fontsize=25)
bp8=sns.regplot(x='bmi',y='expenses',data=df)
bp8.set_xlabel("BMI", fontsize=16)
bp8.set_ylabel("expenses", fontsize=16)
# Out:
# Text(0, 0.5, 'expenses')

# %%
plt.figure(figsize=(15,6))
plt.title("Smokers BMI vs Expenses",fontsize=25)
smokers_bmi=df[df['smoker']=='yes']
bp9=sns.regplot(x='bmi',y='expenses',data=smokers_bmi)
bp9.set_xlabel("BMI", fontsize=16)
bp9.set_ylabel("expenses", fontsize=16)
# Out:
# Text(0, 0.5, 'expenses')

# %%
plt.figure(figsize=(15,6))
plt.title("Non-Smokers BMI vs Expenses",fontsize=25)
non_smokers_bmi=df[df['smoker']=='no']
bp10=sns.regplot(x='bmi',y='expenses',data=non_smokers_bmi)
bp10.set_xlabel("Smokers BMI", fontsize=16)
bp10.set_ylabel("Expenses", fontsize=16)
# Out:
# Text(0, 0.5, 'Expenses')

# %%
cor = df.corr()
plt.figure(figsize=(15,6))
sns.heatmap(cor,fmt='.1g',cmap='Blues')

# %%
df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder, StandardScaler ,FunctionTransformer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

# %%
features = df.drop(['expenses'],axis=1)
target = df['expenses']

# %%
num_col = features.select_dtypes(exclude='O').columns
cat_col = features.select_dtypes(include='O').columns

# %%
print(num_col)
print(cat_col)
# Out:
# Index(['age', 'bmi', 'children'], dtype='object')
# Index(['sex', 'smoker', 'region'], dtype='object')

# %%
columns = ['age', 'bmi', 'children','sex', 'smoker', 'region']

# %%
cat_pipeline = Pipeline([
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('encoder',OrdinalEncoder())
])
num_pipeline = Pipeline([
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',StandardScaler())
])
column_transformer = ColumnTransformer([
    ('num_pipe',num_pipeline,num_col),
    ('cat_pipe',cat_pipeline,cat_col)],
    remainder = 'passthrough'
)

# %%
features1 = column_transformer.fit_transform(features)
features1
# Out:
# array([[-1.43876426, -0.4536457 , -0.90861367,  0.        ,  1.        ,
#          3.        ],
#        [-1.50996545,  0.51418574, -0.07876719,  1.        ,  0.        ,
#          2.        ],
#        [-0.79795355,  0.38295436,  1.58092576,  1.        ,  0.        ,
#          2.        ],
#        ...,
#        [-1.50996545,  1.02270734, -0.90861367,  0.        ,  0.        ,
#          2.        ],
#        [-1.29636188, -0.79812808, -0.90861367,  0.        ,  0.        ,
#          3.        ],
#        [ 1.55168573, -0.25679863, -0.90861367,  0.        ,  1.        ,
#          1.        ]])

# %%
features2 = pd.DataFrame(features1, columns = columns)

# %%
target
# Out:
# 0       16884.92
# 1        1725.55
# 2        4449.46
# 3       21984.47
# 4        3866.86
#           ...
# 1333    10600.55
# 1334     2205.98
# 1335     1629.83
# 1336     2007.95
# 1337    29141.36
# Name: expenses, Length: 1338, dtype: float64

# %%
df1= pd.concat([features2,target],axis=1)

# %%
df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(features2,target,test_size=.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import  ExtraTreesRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

models = {
                'Linear_Reg' : LinearRegression(),
                'DTree' : DecisionTreeRegressor(min_samples_leaf=.0001),
                'RForest' : RandomForestRegressor(n_estimators=500,random_state=329,min_samples_leaf=.0001),
                'RForest1' : RandomForestRegressor(n_estimators=100,random_state=329,min_samples_leaf=.0001),
                'ETree' : ExtraTreesRegressor(n_estimators = 100),
                'GradientBoosting' :GradientBoostingRegressor(n_estimators=70,learning_rate=0.1)

            }

# %%
def evaluate_model(X_train,X_test,y_train,y_test,models):
    report={}
    for i in range(len(models)):
        model=list(models.values())[i]
        # Train model
        model.fit(X_train,y_train)



        #Predict testing data
        y_pred = model.predict(X_test)

        # to get r2 score for test prediction
        test_model_score = r2_score(y_test,y_pred)*100

        report[list(models.keys())[i]] = test_model_score
        print(report)

    return report

# %%
evaluate_model(X_train, X_test, y_train, y_test,models)
# Out:
# {'Linear_Reg': 76.68958783864169}
# {'Linear_Reg': 76.68958783864169, 'DTree': 74.6301312088}
# {'Linear_Reg': 76.68958783864169, 'DTree': 74.6301312088, 'RForest': 85.11489678261408}
# {'Linear_Reg': 76.68958783864169, 'DTree': 74.6301312088, 'RForest': 85.11489678261408, 'RForest1': 85.17488598026779}
# {'Linear_Reg': 76.68958783864169, 'DTree': 74.6301312088, 'RForest': 85.11489678261408, 'RForest1': 85.17488598026779, 'ETree': 84.01035269122018}
# {'Linear_Reg': 76.68958783864169,
#  'DTree': 74.6301312088,
#  'RForest': 85.11489678261408,
#  'RForest1': 85.17488598026779,
#  'ETree': 84.01035269122018}

# %%
model_report:dict = evaluate_model(X_train, X_test, y_train, y_test,models)
# Out:
# {'Linear_Reg': 76.68958783864169}
# {'Linear_Reg': 76.68958783864169, 'DTree': 72.44734337980974}
# {'Linear_Reg': 76.68958783864169, 'DTree': 72.44734337980974, 'RForest': 85.11489678261408}
# {'Linear_Reg': 76.68958783864169, 'DTree': 72.44734337980974, 'RForest': 85.11489678261408, 'RForest1': 85.17488598026779}
# {'Linear_Reg': 76.68958783864169, 'DTree': 72.44734337980974, 'RForest': 85.11489678261408, 'RForest1': 85.17488598026779, 'ETree': 84.29844535178295}

# %%
best_model_score = max(sorted(model_report.values()))

best_model_name = list(model_report.keys())[
    list(model_report.values()).index(best_model_score)
]

best_model = models[best_model_name]

print(f'Best Model Found , Model Name : {best_model_name} , R2 Score : {best_model_score}')
# Out:
# Best Model Found , Model Name : RForest1 , R2 Score : 85.17488598026779

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gb =GradientBoostingRegressor(n_estimators=70,learning_rate=0.1)

# %%
gb.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(n_estimators=70)

# %%
y_pred  = gb.predict(X_test)

# %%
r2_score(y_test,y_pred)*100
# Out:
# 86.35775565769264

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8654901031829366

# %%
gb.score(X_test, y_test)
# Out:
# 0.8635775565769264

# %%
RForest1 = RandomForestRegressor(n_estimators=100,random_state=329,min_samples_leaf=.0001)

# %%
RForest1.fit(X_train,y_train)
# Out:
# RandomForestRegressor(min_samples_leaf=0.0001, random_state=329)

# %%
y_pred = RForest1.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8517488598026779

# %%
RForest1.score(X_test, y_test)
# Out:
# 0.8517488598026779
